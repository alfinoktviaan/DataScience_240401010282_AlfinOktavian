# %% [markdown]
# Nama: Alfin Oktavian
#
# NIM: 240401010282
#
# Kelas: IF-403

# %%
# PERTEMUAN 1: Notebook Pertama Data Science

# SEL 1: Output sederhana
print("Halo, Universitas Siber Asia!")

# SEL 2: Variabel dan tipe data dasar
nama       = "Alfin Oktavian"#string
prodi      = "Teknik Informatika"#string
angkatan   = 2024#integer

print(f"Halo, nama saya {nama} prodi {prodi} angkatan {angkatan}!")


# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")

# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Alfin Oktavian", "Informatika", 2024)
print(hasil)
# Out:
# Halo, Universitas Siber Asia!
# Halo, nama saya Alfin Oktavian prodi Teknik Informatika angkatan 2024!
#
# Tools Data Science yang akan kita pelajari:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. GitHub
# Hai! Saya Alfin Oktavian dari Informatika, angkatan 2024.

# %% [markdown]
# Kesimpulan singkat:
#
#
# Pada praktikum Pertemuan 1, saya mempelajari dasar-dasar pemrograman Python yang digunakan dalam Data Science, seperti menampilkan output, membuat variabel, menggunakan tipe data dasar, mengelola data dalam bentuk list, menggunakan perulangan, dan membuat fungsi sederhana.
#
# Temuan utama dari praktikum ini adalah bahwa Python memiliki sintaks yang mudah dipahami dan dapat digunakan untuk mengotomatisasi berbagai proses pengolahan data.
#
# Keterbatasan pada pertemuan ini adalah materi masih berfokus pada konsep dasar sehingga belum membahas pengolahan data secara langsung.
